# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np

# %%
# Reading non-symmetric input data

df = pd.read_csv('SA_AAL_rg.csv')
for column in df:
    if df[column].dtype == np.object_:
        df[column] = df[column].str.replace('\+AC0-', '-').astype(float)
df = df.fillna(1)
df.head()
# Out:
#    PreCG+AF8-L+AF8-SA  SFGdor+AF8-L+AF8-SA  ORBsup+AF8-L+AF8-SA  \
# 0            1.000000             0.781541             0.599987
# 1            0.784238             1.000000             0.654876
# 2            0.629777             0.687242             1.000000
# 3            0.890097             0.895069             0.799320
# 4            0.832424             0.999978             1.000000
#
#    MFG+AF8-L+AF8-SA  ORBmid+AF8-L+AF8-SA  IFGoperc+AF8-L+AF8-SA  \
# 0          0.907600             0.759068               0.890024
# 1          0.889251             0.984121               0.894396
# 2          0.810324             0.999996               0.999980
# 3          1.000000             0.709482               0.863991
# 4          0.716031             1.000000               0.970398
#
#    IFGtriang+AF8-L+AF8-SA  ORBinf+AF8-L+AF8-SA  ROL+AF8-L+AF8-SA  \
# 0                0.511923             0.712339          0.682941
# 1                0.481911             0.581138          0.630645
# 2                0.621117             0.891096          0.850146
# 3                0.783207             0.999548          0.600411
# 4               -0.066657             1.000000          0.860315
#
#    SMA+AF8-L+AF8-SA        ...         SMG+AF8-R+AF8-SA  ANG+AF8-R+AF8-SA  \
# 0          0.708343        ...                 0.463328          0.466748
# 1          0.885451        ...                 0.208085          0.485249
# 2          0.776977        ...                 0.500591          0.576539
# 3          0.910495        ...                 0.721157          0.503557
# 4          0.999001        ...                 0.472784          0.987902
#
#    PCUN+AF8-R+AF8-SA  PCL+AF8-R+AF8-SA  HES+AF8-R+AF8-SA  STG+AF8-R+AF8-SA  \
# 0           0.558368          0.661737               1.0          0.616721
# 1           0.610696          0.802549               1.0          0.660234
# 2           0.880757          0.849701               1.0          0.999999
# 3           0.646183          0.847648               1.0          0.593679
# 4           0.978636          0.998612               1.0          0.921856
#
#    TPOsup+AF8-R+AF8-SA  MTG+AF8-R+AF8-SA  TPOmid+AF8-R+AF8-SA  \
# 0             0.692335          0.703851             1.000000
# 1             0.583257          0.668746             1.000000
# 2             0.687351          0.660426             1.000000
# 3             0.739358          0.720155             0.999984
# 4             0.746108          0.690314             0.999974
#
#    ITG+AF8-R+AF8-SA
# 0          0.698570
# 1          0.534557
# 2          0.867181
# 3          0.705786
# 4          0.999850
#
# [5 rows x 78 columns]

# %%
# Removing values <0, > 1 and thresholding (if needed)

for i in range(78):
    for j in range(78):
        if df.iloc[i,j] < 0:
            df.iloc[i,j] = 0
        if df.iloc[i,j] > 1:
            df.iloc[i,j] = 1
        # Thresholding
        #if df.iloc[i,j] < 0.5:
         #   df.iloc[i,j] = 0
df.head()
# Out:
#    PreCG+AF8-L+AF8-SA  SFGdor+AF8-L+AF8-SA  ORBsup+AF8-L+AF8-SA  \
# 0            1.000000             0.781541             0.599987
# 1            0.784238             1.000000             0.654876
# 2            0.629777             0.687242             1.000000
# 3            0.890097             0.895069             0.799320
# 4            0.832424             0.999978             1.000000
#
#    MFG+AF8-L+AF8-SA  ORBmid+AF8-L+AF8-SA  IFGoperc+AF8-L+AF8-SA  \
# 0          0.907600             0.759068               0.890024
# 1          0.889251             0.984121               0.894396
# 2          0.810324             0.999996               0.999980
# 3          1.000000             0.709482               0.863991
# 4          0.716031             1.000000               0.970398
#
#    IFGtriang+AF8-L+AF8-SA  ORBinf+AF8-L+AF8-SA  ROL+AF8-L+AF8-SA  \
# 0                0.511923             0.712339          0.682941
# 1                0.481911             0.581138          0.630645
# 2                0.621117             0.891096          0.850146
# 3                0.783207             0.999548          0.600411
# 4                0.000000             1.000000          0.860315
#
#    SMA+AF8-L+AF8-SA        ...         SMG+AF8-R+AF8-SA  ANG+AF8-R+AF8-SA  \
# 0          0.708343        ...                 0.463328          0.466748
# 1          0.885451        ...                 0.208085          0.485249
# 2          0.776977        ...                 0.500591          0.576539
# 3          0.910495        ...                 0.721157          0.503557
# 4          0.999001        ...                 0.472784          0.987902
#
#    PCUN+AF8-R+AF8-SA  PCL+AF8-R+AF8-SA  HES+AF8-R+AF8-SA  STG+AF8-R+AF8-SA  \
# 0           0.558368          0.661737               1.0          0.616721
# 1           0.610696          0.802549               1.0          0.660234
# 2           0.880757          0.849701               1.0          0.999999
# 3           0.646183          0.847648               1.0          0.593679
# 4           0.978636          0.998612               1.0          0.921856
#
#    TPOsup+AF8-R+AF8-SA  MTG+AF8-R+AF8-SA  TPOmid+AF8-R+AF8-SA  \
# 0             0.692335          0.703851             1.000000
# 1             0.583257          0.668746             1.000000
# 2             0.687351          0.660426             1.000000
# 3             0.739358          0.720155             0.999984
# 4             0.746108          0.690314             0.999974
#
#    ITG+AF8-R+AF8-SA
# 0          0.698570
# 1          0.534557
# 2          0.867181
# 3          0.705786
# 4          0.999850
#
# [5 rows x 78 columns]

# %%
# Inverting the data
    # looking at dissim instead of sim
    # same as agglomerating vs. separating data
# for i in range(78):
#     for j in range(78):
#         a = df.iloc[i,j]
#         df.iloc[i,j] = 1-a
# df.head()

# %%
# Making dataset symmetric

for i in range(78):
    for j in range(i+1):
        df.iloc[j,i] = df.iloc[i,j]
df.head()
# Out:
#    PreCG+AF8-L+AF8-SA  SFGdor+AF8-L+AF8-SA  ORBsup+AF8-L+AF8-SA  \
# 0            1.000000             0.784238             0.629777
# 1            0.784238             1.000000             0.687242
# 2            0.629777             0.687242             1.000000
# 3            0.890097             0.895069             0.799320
# 4            0.832424             0.999978             1.000000
#
#    MFG+AF8-L+AF8-SA  ORBmid+AF8-L+AF8-SA  IFGoperc+AF8-L+AF8-SA  \
# 0          0.890097             0.832424               0.933154
# 1          0.895069             0.999978               0.909066
# 2          0.799320             1.000000               0.991127
# 3          1.000000             0.716031               0.872615
# 4          0.716031             1.000000               0.960506
#
#    IFGtriang+AF8-L+AF8-SA  ORBinf+AF8-L+AF8-SA  ROL+AF8-L+AF8-SA  \
# 0                0.548034             0.728044          0.672902
# 1                0.528547             0.625199          0.563026
# 2                0.622488             0.894325          0.823488
# 3                0.993362             0.994414          0.599904
# 4                0.000000             1.000000          0.697320
#
#    SMA+AF8-L+AF8-SA        ...         SMG+AF8-R+AF8-SA  ANG+AF8-R+AF8-SA  \
# 0          0.750941        ...                 0.508362          0.491821
# 1          0.863614        ...                 0.251759          0.522575
# 2          0.778884        ...                 0.502731          0.586074
# 3          0.916665        ...                 0.790178          0.526830
# 4          0.999995        ...                 0.483538          0.803410
#
#    PCUN+AF8-R+AF8-SA  PCL+AF8-R+AF8-SA  HES+AF8-R+AF8-SA  STG+AF8-R+AF8-SA  \
# 0           0.571127          0.692164          0.999954          0.594443
# 1           0.629081          0.828654          0.999793          0.639218
# 2           0.845775          0.806240          1.000000          0.999972
# 3           0.660794          0.828353          0.999747          0.597569
# 4           0.771810          0.941510          0.999999          0.173535
#
#    TPOsup+AF8-R+AF8-SA  MTG+AF8-R+AF8-SA  TPOmid+AF8-R+AF8-SA  \
# 0             0.687678          0.715770             1.000000
# 1             0.575672          0.686880             0.999917
# 2             0.643088          0.652312             0.999994
# 3             0.731769          0.730992             0.999996
# 4             0.706281          0.691096             0.982094
#
#    ITG+AF8-R+AF8-SA
# 0          0.704727
# 1          0.549691
# 2          0.817198
# 3          0.719055
# 4          0.999997
#
# [5 rows x 78 columns]

# %%
# Heatmap of the data

fig= plt.figure(figsize=(7,7))
plt.imshow(df, cmap='YlGnBu', interpolation='nearest')
plt.show()

# %%
# Clustering: 

import seaborn as sns; sns.set(color_codes=True) # default is Euclidian
g = sns.clustermap(df, method='average',cmap='YlGnBu') # try single, ward, complete method as well

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
a = linkage(df,'single')
fig = plt.figure(figsize=(25, 10))
#dn = dendrogram(a,truncate_mode='lastp')
dn = dendrogram(a)
plt.show()

# %%
a = linkage(df,'ward')
fig = plt.figure(figsize=(25, 10))
#dn = dendrogram(a)
dn = dendrogram(a,truncate_mode='lastp')
plt.show()
